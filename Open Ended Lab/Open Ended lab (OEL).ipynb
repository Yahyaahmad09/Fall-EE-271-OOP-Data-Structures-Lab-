# %% [markdown]
# <h1 style="color: blue; font-family: Arial, sans-serif; text-align: center;">EE-271 “OOP & Data Structures Lab”</h1>

# %% [markdown]
# | **Field**        | **Details**         |
# |-------------------|---------------------|
# | **Name**         | Yahya Ahmad         |
# | **Req No**       | 23jzele0528         |
# | **Lab Tile**          |Open Ended lab (OEL)|
# | **Lab No**| 14                  |

# %% [markdown]
# # <span style="color: blue; font-size: 1em;">🏠 Problem Statement</span>
#
# This lab aims to understand **statistical analysis** to explore the relationship between house features and how these variables are used to predict house prices.
#
# ---

# %% [markdown]
# # <span style="color: green; font-size: 1em;">🎯 Objective</span>
#
# The key objectives of this lab are:
#
# 1. **Utilization of OOP Concepts**:
#    - Understand the structure of different libraries using Object-Oriented Programming (OOP) concepts.
#    - Apply OOP principles to organize and structure the code effectively.
#
# 2. **Exploratory Data Analysis (EDA)**:
#    - Perform EDA to understand the dataset, identify patterns, and uncover insights about house features and prices.
#
# 3. **House Price Prediction**:
#    - Build a predictive model to estimate house prices based on the given features.
#
# 4. **Model Comparison**:
#    - Use **two different models** to minimize the difference between predicted and actual house prices.
#    - Compare the performance of the models to determine the best fit.
#
# ---

# %% [markdown]
# # <span style="color: blue; font-size: 1em;">📊 Dataset</span>
#
# The dataset for this lab is available on **Kaggle**. You can download it from the following link:
#
# - [House Sales Prediction Dataset](https://www.kaggle.com/datasets/harlfoxem/housesalesprediction)
#
# ---

# %% [markdown]
# # <span style="color: green; font-size: 1em;">📚 Recommended Reading</span>
#
# To gain a deeper understanding of the concepts and techniques used in this lab, you can refer to the following resources:
#
# - **Blog**: [House Prices Prediction Using Deep Learning](https://towardsdatascience.com/house-prices-prediction-using-deep-learning-dea265cc3154)
# - **Video Lectures**: Explore online tutorials and video lectures on OOP, Data Analysis, and Machine Learning.
# - **Documentation**: Refer to the official documentation of libraries like `pandas`, `numpy`, `matplotlib`, and `scikit-learn`.
#
# ---

# %% [markdown]
# # <span style="color: purple; font-size: 1em;">📝 Rubrics</span>
#
# The evaluation of this lab will be based on the following criteria:
#
# 1. **Understanding Libraries**:
#    - Demonstrate an understanding of different Python libraries and their purpose (e.g., `pandas`, `numpy`, `matplotlib`, `scikit-learn`).
#
# 2. **OOP Concepts**:
#    - Identify and implement **five key OOP concepts** in your code:
#      - Classes and Objects
#      - Inheritance
#      - Polymorphism
#      - Encapsulation
#      - Abstraction
#
# 3. **Exploratory Data Analysis (EDA)**:
#    - Perform EDA to analyze the dataset and derive insights.
#
# 4. **Model Building**:
#    - Build and compare **two models** for house price prediction.
#    - Evaluate the models based on their performance metrics.
#
# 5. **Code Quality**:
#    - Write clean, well-structured, and documented code.
#
# ---

# %% [markdown]
# <div style="background-color: #f0f8ff; padding: 10px; border-radius: 5px;">
#     <p style="font-weight: bold; color: #333;">Let's build something amazing! 🌟</p>
# </div>

# %% [markdown]
# # <span style="color: darkgreen; font-size: 1em;"> Overview of Python Libraries use in this lab </span>
#
# Here’s a brief overview of the libraries you listed, along with their purposes, key features, and use cases:
#
# ---
#
# ## <span style="color: green; font-size: 1em;"> 1. Pandas</span>
# - **Purpose**: Data manipulation and analysis.
# - **Key Features**:
#   - Provides data structures like **DataFrames** and **Series**.
#   - Ideal for handling structured data.
#   - Offers tools for reading/writing data, cleaning, transforming, and analyzing datasets.
# - **Use Case**: Data preprocessing, data cleaning, and exploratory data analysis (EDA).
#
# ---
#
# ## <span style="color: green; font-size: 1em;"> 2. NumPy</span>
# - **Purpose**: Numerical computing.
# - **Key Features**:
#   - Provides support for arrays, matrices, and mathematical functions.
#   - Foundation for many other data science libraries.
# - **Use Case**: Performing mathematical operations, linear algebra, and statistical computations.
#
# ---
#
# ## <span style="color: green; font-size: 1em;"> 3. Scitit-learn</span>
# - **Purpose**: Machine learning.
# - **Key Features**:
#   - Offers tools for data mining and analysis.
#   - Includes algorithms for classification, regression, clustering, dimensionality reduction, and model selection.
# - **Use Case**: Building and evaluating machine learning models.
#
# ---
#
# ## <span style="color: green; font-size: 1em;"> 4. TensorFlow</span>
# - **Purpose**: Deep learning and neural networks.
# - **Key Features**:
#   - Open-source library developed by Google.
#   - Designed for numerical computation and large-scale machine learning.
#   - Well-suited for deep learning applications.
# - **Use Case**: Developing and training deep learning models, including neural networks.
#
# ---
#
# ## <span style="color: green; font-size: 1em;"> 5. Seaborn</span>
# - **Purpose**: Statistical data visualization.
# - **Key Features**:
#   - Built on top of **Matplotlib**.
#   - Provides a high-level interface for creating attractive and informative statistical graphics.
# - **Use Case**: Creating complex visualizations like heatmaps, pair plots, and violin plots with minimal code.
#
# ---
#
# ## <span style="color: green; font-size: 1em;"> 6. Matplotlab</span>
# - **Purpose**: Data visualization.
# - **Key Features**:
#   - Comprehensive library for creating static, animated, and interactive visualizations.
#   - Highly customizable and forms the base for many other visualization libraries.
# - **Use Case**: Creating a wide range of plots, including line plots, bar charts, scatter plots, and histograms.
#
# ---
#
# ## <span style="color: purple; font-size: 1em;"> Common Workflow Using These Libraries</span>
# 1. **Data Loading and Cleaning**: Use **Pandas** to load and clean your dataset.
# 2. **Numerical Operations**: Use **NumPy** for numerical computations or transformations.
# 3. **Data Visualization**: Use **Matplotlib** and **Seaborn** to visualize data and gain insights.
# 4. **Machine Learning**: Use **Scikit-Learn** to build and evaluate machine learning models.
# 5. **Deep Learning**: Use **TensorFlow** for more complex models, especially neural networks.
#
# ---
#
# These libraries are often used together in to a module which predict the house price

# %% [markdown]
# ## <span style="color: green; font-size: 1em;"> Importing Required Libraries</span>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn import metrics

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization

# %% [markdown]
# ## <span style="color: green; font-size: 1em;"> Step 1: Exploratory Data Analysis (EDA)</span>
# The first step in any `data analysis` or `machine learning project` is to understand the dataset. This involves loading the data, inspecting its structure, and performing initial explorations to gain insights.

# %% [markdown]
# ## <span style="color: blue; font-size: 1em;"> Reading the File with Pandas</span>
#
# The **Pandas** library is a powerful tool for reading and manipulating data in Python. It supports various file formats, such as CSV, Excel, and more. Once the data is loaded, we can perform operations like cleaning, scaling, and plotting.
#
# ---
#
# ### <span style="color: blue; font-size: 1em;"> Reading the File</span>
# Pandas provides functions to read different types of files. Below are examples of reading CSV and Excel files:

# %% [markdown]
# ## <span style="color: green; font-size: 1em;"> Reading a Csv file</span>

# %%
data = pd.read_csv(r'C:\Users\Computer Zone\Downloads\archive\kc_house_data.csv')

# %% [markdown]
# ### <span style="color: green; font-size: 1em;"> First five Rows</span>

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ### <span style="color: green; font-size: 1em;"> Last five Rows</span>

# %%
data.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %% [markdown]
# ### <span style="color: green; font-size: 1em;"> Info of the data</span>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# ### <span style="color: green; font-size: 1em;"> Describtion of Data</span>

# %%
data.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# ...

# %% [markdown]
# ### <span style="color: green; font-size: 1em;"> Visualizing House Prices</span>

# %%
fig = plt.figure(figsize=(10,7))
fig.add_subplot(2,1,1)
sns.distplot(data['price'])
fig.add_subplot(2,1,2)
sns.boxplot(data['price'])
plt.tight_layout()
# Out:
# C:\Users\Computer Zone\AppData\Local\Temp\ipykernel_14776\2334536986.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['price'])

# %% [markdown]
# #### <span style="color: green; font-size: 1.3em;"> Ploting and Sub Ploting </span>

# %%
fig = plt.figure(figsize=(16, 5))

# Subplot 1
ax1 = fig.add_subplot(2, 2, 1)
sns.scatterplot(x='sqft_above', y='price', data=data, ax=ax1)

# Subplot 2
ax2 = fig.add_subplot(2, 2, 2)
sns.scatterplot(x='sqft_lot', y='price', data=data, ax=ax2)

# Subplot 3
ax3 = fig.add_subplot(2, 2, 3)
sns.scatterplot(x='sqft_living', y='price', data=data, ax=ax3)

# Subplot 4
ax4 = fig.add_subplot(2, 2, 4)
sns.scatterplot(x='sqft_basement', y='price', data=data, ax=ax4)

plt.show()

# %% [markdown]
# ### <span style="color: green; font-size: 1em;"> Visualizing Bedrooms,Bathrooms,Floors,Grade</span>

# %%
fig = plt.figure(figsize=(15,7))
fig.add_subplot(2,2,1)
sns.histplot(data['bedrooms'])
fig.add_subplot(2,2,2)
sns.histplot(data['floors'])
fig.add_subplot(2,2,3)
sns.histplot(data['bathrooms'])
fig.add_subplot(2,2,4)
sns.histplot(data['grade'])
plt.tight_layout()

# %% [markdown]
# ### <span style="color: green; font-size: 1em;"> Break Date to Years, Months</span>

# %%
data['date'] = pd.to_datetime(data['date'])
data['month'] = data['date'].apply(lambda date:date.month)
data['year'] = data['date'].apply(lambda date:date.year)

# %% [markdown]
# ### <span style="color: green; font-size: 1em;"> Data Visualization House Price vs Months and Years</span>

# %%
fig = plt.figure(figsize=(16,5))
fig.add_subplot(1,2,1)
data.groupby('month').mean()['price'].plot()
fig.add_subplot(1,2,2)
data.groupby('year').mean()['price'].plot()
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ### <span style="color: green; font-size: 1em;"> Check For Missing Values</span>

# %%
data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# month            0
# year             0
# dtype: int64

# %% [markdown]
# ### <span style="color: green; font-size: 1em;"> Drop Some Unnecessary Columns</span>

# %%
data = data.drop('date',axis=1)
data = data.drop('id',axis=1)
data = data.drop('zipcode',axis=1)

# %% [markdown]
# # <span style="color: blue; font-size: 1em;"> Step 2: Dataset Preparation (Splitting and Scaling)</span>
# 1) Data is divided into the **`Train set`** and **`Test set`**.
# 2) We use the `Train set` to make the algorithm learn the `data’s` behavior and then check the accuracy of our model on the `Test set`.
#
# ##### ***Features (X):***
#      The columns that are inserted into our model will be used to make predictions.
# ##### ***Prediction (y):***
#      Target variable that will be predicted by the features

# %%
data.dropna(inplace=True)

# %% [markdown]
# #### <span style="color: blue; font-size: 1em;"> Remove the price column from the Data</span>

# %%
X = data.drop('price',axis =1).values

# %% [markdown]
# #### <span style="color: blue; font-size: 1em;"> Get the price column from the Data</span>

# %%
y = data['price'].values

# %% [markdown]
# #### <span style="color: blue; font-size: 1em;"> Spliting Data into Train and Test </span>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %% [markdown]
# #### <span style="color: blue; font-size: 1em;"> Scale the Data ito Train and Test </span>

# %%
s_scaler = StandardScaler()
X_train = s_scaler.fit_transform(X_train)
X_test = s_scaler.transform(X_test)

# %% [markdown]
# #### <span style="color: green; font-size: 1.5em;"> Step 3: Model Selection and Evaluation </span>
#  #### <span style="color: blue; font-size: 1.25em;"> 💡Model 1: Multiple Linear Regressions</span>
#  Multiple Linear Regressions **`Multiple Linear Regression`** is an extension of *`Simple Linear Regression`* and assume that there is a linear relationship between a dependent variable `Y` and independent variables `X`
#
# Let’s wrap the training process in our Regression model:

# %% [markdown]
# #### <span style="color: green; font-size: 1em;"> Multiple Regerssion </span>

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### <span style="color: green; font-size: 1em;"> Checking the Model Coefficients </span>

# %%
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# 540068.0331492655
# [-32174.26458621  28314.47160234  80960.8365489    6428.24177905
#    3413.70406639  49942.35152741  36835.82051685  21903.68879982
#  116003.40529456  76073.5117404   25375.83805414 -72994.52529983
#    7676.57141888  78057.84710672 -17254.48220907  18909.70160034
#  -10301.37920458   4182.48580611  17081.43533197]

# %% [markdown]
# #### <span style="color: green; font-size: 1.5em;"> Prediction </span>

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# #### <span style="color: green; font-size: 1em;"> Convert the Coefficient into a DataForm </span>

# %%
coeff_df = pd.DataFrame(regressor.coef_, data.drop('price',axis =1).columns, columns=['Coefficient']) 
coeff_df
# Out:
#                  Coefficient
# bedrooms       -32174.264586
# bathrooms       28314.471602
# sqft_living     80960.836549
# sqft_lot         6428.241779
# floors           3413.704066
# waterfront      49942.351527
# view            36835.820517
# condition       21903.688800
# grade          116003.405295
# sqft_above      76073.511740
# sqft_basement   25375.838054
# yr_built       -72994.525300
# yr_renovated     7676.571419
# lat             78057.847107
# long           -17254.482209
# sqft_living15   18909.701600
# sqft_lot15     -10301.379205
# month            4182.485806
# year            17081.435332

# %% [markdown]
# #### <span style="color: green; font-size: 1.1em;"> Visualizating Y_test and Predict </span>

# %%
fig = plt.figure(figsize=(10,5))
residuals = (y_test- y_pred)
sns.distplot(residuals)
# Out:
# C:\Users\Computer Zone\AppData\Local\Temp\ipykernel_14776\1700944608.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residuals)
# <Axes: ylabel='Density'>

# %% [markdown]
# #### <span style="color: green; font-size: 1.2em;"> Compare the Actual and Predicted Values </span>
# Let’s compare **`actual output`** and **`predicted value`** to measure how far our predictions are from the `real house prices`

# %%
y_pred = regressor.predict(X_test)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1 = df.head(10)
df1
# Out:
#      Actual      Predicted
# 0  349950.0  530667.784120
# 1  450000.0  667025.076946
# 2  635000.0  553195.043391
# 3  355500.0  346657.166101
# 4  246950.0   61378.186019
# 5  406550.0  481162.809294
# 6  350000.0  312819.788488
# 7  226500.0  273833.027682
# 8  265000.0  280571.649291
# 9  656000.0  532966.844438

# %%
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))  
print('MSE:', metrics.mean_squared_error(y_test, y_pred))  
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('VarScore:',metrics.explained_variance_score(y_test,y_pred))
# Out:
# MAE: 125933.74319633955
# MSE: 40601153229.61856
# RMSE: 201497.27846702686
# VarScore: 0.7039747986273114

# %% [markdown]
# #### <span style="color: blue; font-size: 1.25em;"> 💡Model 2: Keras Regressions </span>
# Let’s create a baseline **`neural network model`** for the regression problem. Starting with all of the needed functions and objects.

# %% [markdown]
# #### <span style="color: blue; font-size: 1em;"> Creating a Sequential Model </span>
# - Then, we train the model for `400 epochs`, and each time record the training and `validation accuracy` in the history object.
# - To keep track of how well the model is performing for each epoch, the model will run in both `train` and `test` data along with calculating the `loss function`.

# %%
model = Sequential()
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(1))
model.compile(optimizer='Adam',loss='mes')

# %%
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# %% [markdown]
# #### <span style="color: blue; font-size: 1em;"> Train Neural Network </span>
# - Summary

# %%
model.fit(x=X_train,y=y_train,validation_data=(X_test,y_test),batch_size=128,epochs=400)
model.summary()
# Out:
# Epoch 1/400
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 432179609600.0000 - mae: 542806.0000 - val_loss: 428824788992.0000 - val_mae: 540083.0000
# Epoch 2/400
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 422550634496.0000 - mae: 538291.2500 - val_loss: 424596439040.0000 - val_mae: 537216.4375
# Epoch 3/400
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 407820763136.0000 - mae: 532023.3125 - val_loss: 378784841728.0000 - val_mae: 505693.9688
# Epoch 4/400
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 346467008512.0000 - mae: 481858.6562 - val_loss: 222008164352.0000 - val_mae: 376000.1875
# Epoch 5/400
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 169589309440.0000 - mae: 325596.1250 - val_loss: 82382381056.0000 - val_mae: 211531.0156
# Epoch 6/400
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 83840655360.0000 - mae: 208881.8438 - val_loss: 66292539392.0000 - val_mae: 188753.3906
# Epoch 7/400
# ...

# %% [markdown]
# #### <span style="color: blue; font-size: 1.2em;"> Visualizing the losses </span>

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot(figsize=(12,8))
# Out:
# <Axes: >

# %% [markdown]
# #### <span style="color: blue; font-size: 1em;"> Evaluation on Test Data¶ </span>

# %%
y_pred = model.predict(X_test)

print('MAE:', metrics.mean_absolute_error(y_test, y_pred))  
print('MSE:', metrics.mean_squared_error(y_test, y_pred))  
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('VarScore:',metrics.explained_variance_score(y_test,y_pred))
# Out:
# 223/223 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# MAE: 79183.25403713374
# MSE: 16817107509.91298
# RMSE: 129680.79082853011
# VarScore: 0.8776709082864358

# %% [markdown]
# #### <span style="color: blue; font-size: 1em;"> Visualizing Our Prediction </span>

# %%
fig = plt.figure(figsize=(10,5))
plt.scatter(y_test,y_pred)

# %% [markdown]
# #### <span style="color: blue; font-size: 1em;"> Perfecr Prediction </span>

# %%
dplt.plot(y_test,y_test,'r')

# %% [markdown]
# #### <span style="color: blue; font-size: 1em;"> Visualizing Residuals </span>

# %%
fig = plt.figure(figsize=(10,5))
residuals = (y_test- y_pred)
sns.distplot(residuals)
# Out:
# C:\Users\Computer Zone\AppData\Local\Temp\ipykernel_14776\2877839159.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residuals)
# <Axes: ylabel='Density'>
